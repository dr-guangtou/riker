# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import warnings

from tqdm import tnrange, tqdm_notebook
import multiprocessing as mp

import matplotlib.pyplot as plt
from matplotlib import rcParams

from astropy.utils.console import ProgressBar

from riker.galaxy import GalaxyMap
from riker.data import BeneMassAgeZMaps


warnings.filterwarnings("ignore")

plt.rc('text', usetex=True)
rcParams.update({'axes.linewidth': 1.5})
rcParams.update({'xtick.direction': 'in'})
rcParams.update({'ytick.direction': 'in'})
rcParams.update({'xtick.minor.visible': 'True'})
rcParams.update({'ytick.minor.visible': 'True'})
rcParams.update({'xtick.major.pad': '7.0'})
rcParams.update({'xtick.major.size': '8.0'})
rcParams.update({'xtick.major.width': '1.5'})
rcParams.update({'xtick.minor.pad': '7.0'})
rcParams.update({'xtick.minor.size': '4.0'})
rcParams.update({'xtick.minor.width': '1.5'})
rcParams.update({'ytick.major.pad': '7.0'})
rcParams.update({'ytick.major.size': '8.0'})
rcParams.update({'ytick.major.width': '1.5'})
rcParams.update({'ytick.minor.pad': '7.0'})
rcParams.update({'ytick.minor.size': '4.0'})
rcParams.update({'ytick.minor.width': '1.5'})
rcParams.update({'axes.titlepad': '10.0'})
rcParams.update({'font.size': 25})
# Out:
# WARNING: AstropyDeprecationWarning: Composition of model classes will be removed in 4.0 (but composition of model instances is not affected) [astropy.modeling.core]
# Unable to open CL script cache /Users/song/.iraf/pyraf/clcache
# Unable to open CL script cache /Users/song/.iraf/pyraf/clcache.v2
# Warning: unable to open any CL script cache, performance may be slow

# %% [markdown]
# ## Prepare the TNG100 z=0.4 high-resolution HDF5 data

# %%
# Input HDF5 from simulation
tng_dir = '/Users/song/data/massive/simulation/riker/tng'

# HDF5 files
tng_file = os.path.join(tng_dir, 'galaxies_tng100_072_agez_highres.hdf5')

tng_label = 'tng100_z0.4_hres'

tng_data = BeneMassAgeZMaps(tng_file, label=tng_label)

# %% [markdown]
# ### Batch reduction of all galaxies in `xy` projection

# %%
def reduce(idx, hdf5, proj='xz'):
    """Reduce a single galaxy."""
    gal = GalaxyMap(hdf5, idx, proj=proj, aper_force=None)
    summary = gal.run_all(plot=False, output=True)
    
    return summary

# %%
xz_sum = []

for idx in range(tng_data.n_gal):
    print("# Dealing with galaxz: {}".format(idx))
    xz_sum.append(reduce(idx, tng_data))
# Out:
# # Dealing with galaxz: 0
# # Dealing with galaxz: 1
# # Dealing with galaxz: 2
# # Dealing with galaxz: 3
# # Dealing with galaxz: 4
# # Dealing with galaxz: 5
# # Dealing with galaxz: 6
# # Dealing with galaxz: 7
# # Dealing with galaxz: 8
# # Dealing with galaxz: 9
# # Dealing with galaxz: 10
# # Dealing with galaxz: 11
# # Dealing with galaxz: 12
# # Dealing with galaxz: 13
# # Dealing with galaxz: 14
# # Dealing with galaxz: 15
# # Dealing with galaxz: 16
# # Dealing with galaxz: 17
# # Dealing with galaxz: 18
# # Dealing with galaxz: 19
# # Dealing with galaxz: 20
# # Dealing with galaxz: 21
# # Dealing with galaxz: 22
# # Dealing with galaxz: 23
# # Dealing with galaxz: 24
# # Dealing with galaxz: 25
# # Dealing with galaxz: 26
# # Dealing with galaxz: 27
# # Dealing with galaxz: 28
# # Dealing with galaxz: 29
# # Dealing with galaxz: 30
# # Dealing with galaxz: 31
# # Dealing with galaxz: 32
# # Dealing with galaxz: 33
# # Dealing with galaxz: 34
# # Dealing with galaxz: 35
# # Dealing with galaxz: 36
# # Dealing with galaxz: 37
# # Dealing with galaxz: 38
# # Dealing with galaxz: 39
# # Dealing with galaxz: 40
# # Dealing with galaxz: 41
# # Dealing with galaxz: 42
# # Dealing with galaxz: 43
# # Dealing with galaxz: 44
# # Dealing with galaxz: 45
# # Dealing with galaxz: 46
# # Dealing with galaxz: 47
# # Dealing with galaxz: 48
# # Dealing with galaxz: 49
# # Dealing with galaxz: 50
# # Dealing with galaxz: 51
# # Dealing with galaxz: 52
# # Dealing with galaxz: 53
# # Dealing with galaxz: 54
# # Dealing with galaxz: 55
# # Dealing with galaxz: 56
# # Dealing with galaxz: 57
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ###  ELLIPSE RUN FAILED IN ATTEMPT:  0
# ###  Error Information :  XXX Can not find the outBin: /Users/song/data/massive/simulation/riker/tng/fits/tng100_z0.4_hres_57_89620_xz_mass_ins_ellip_2.bin!
# ----------------------------------------------------------------------------------------------------
# ###  Maxsma  175.0 -->  157.5
# ----------------------------------------------------------------------------------------------------
# # Dealing with galaxz: 58
# # Dealing with galaxz: 59
# # Dealing with galaxz: 60
# # Dealing with galaxz: 61
# # Dealing with galaxz: 62
# # Dealing with galaxz: 63
# # Dealing with galaxz: 64
# # Dealing with galaxz: 65
# # Dealing with galaxz: 66
# # Dealing with galaxz: 67
# # Dealing with galaxz: 68
# # Dealing with galaxz: 69
# # Dealing with galaxz: 70
# # Dealing with galaxz: 71
# # Dealing with galaxz: 72
# # Dealing with galaxz: 73
# # Dealing with galaxz: 74
# # Dealing with galaxz: 75
# # Dealing with galaxz: 76
# # Dealing with galaxz: 77
# # Dealing with galaxz: 78
# # Dealing with galaxz: 79
# # Dealing with galaxz: 80
# # Dealing with galaxz: 81
# # Dealing with galaxz: 82
# # Dealing with galaxz: 83
# # Dealing with galaxz: 84
# # Dealing with galaxz: 85
# # Dealing with galaxz: 86
# # Dealing with galaxz: 87
# # Dealing with galaxz: 88
# # Dealing with galaxz: 89
# # Dealing with galaxz: 90
# # Dealing with galaxz: 91
# # Dealing with galaxz: 92
# # Dealing with galaxz: 93
# # Dealing with galaxz: 94
# # Dealing with galaxz: 95
# # Dealing with galaxz: 96
# # Dealing with galaxz: 97
# # Dealing with galaxz: 98
# # Dealing with galaxz: 99
# # Dealing with galaxz: 100
# # Dealing with galaxz: 101
# # Dealing with galaxz: 102
# # Dealing with galaxz: 103
# # Dealing with galaxz: 104
# # Dealing with galaxz: 105
# # Dealing with galaxz: 106
# # Dealing with galaxz: 107
# # Dealing with galaxz: 108
# # Dealing with galaxz: 109
# # Dealing with galaxz: 110
# # Dealing with galaxz: 111
# # Dealing with galaxz: 112
# # Dealing with galaxz: 113
# # Dealing with galaxz: 114
# # Dealing with galaxz: 115
# # Dealing with galaxz: 116
# # Dealing with galaxz: 117
# # Dealing with galaxz: 118
# # Dealing with galaxz: 119
# # Dealing with galaxz: 120
# # Dealing with galaxz: 121
# # Dealing with galaxz: 122
# # Dealing with galaxz: 123
# # Dealing with galaxz: 124
# # Dealing with galaxz: 125
# # Dealing with galaxz: 126
# # Dealing with galaxz: 127
# # Dealing with galaxz: 128
# # Dealing with galaxz: 129
# # Dealing with galaxz: 130
# # Dealing with galaxz: 131
# # Dealing with galaxz: 132
# # Dealing with galaxz: 133
# # Dealing with galaxz: 134
# # Dealing with galaxz: 135
# # Dealing with galaxz: 136
# # Dealing with galaxz: 137
# # Dealing with galaxz: 138
# # Dealing with galaxz: 139
# # Dealing with galaxz: 140
# # Dealing with galaxz: 141
# # Dealing with galaxz: 142
# # Dealing with galaxz: 143
# # Dealing with galaxz: 144
# # Dealing with galaxz: 145
# # Dealing with galaxz: 146
# # Dealing with galaxz: 147
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ###  ELLIPSE RUN FAILED IN ATTEMPT:  0
# ###  Error Information :  XXX Can not find the outBin: /Users/song/data/massive/simulation/riker/tng/fits/tng100_z0.4_hres_147_173224_xz_mass_gal_ellip_2.bin!
# ----------------------------------------------------------------------------------------------------
# ###  Maxsma  175.0 -->  157.5
# ----------------------------------------------------------------------------------------------------
# # Dealing with galaxz: 148
# # Dealing with galaxz: 149
# # Dealing with galaxz: 150
# # Dealing with galaxz: 151
# # Dealing with galaxz: 152
# # Dealing with galaxz: 153
# # Dealing with galaxz: 154
# # Dealing with galaxz: 155
# # Dealing with galaxz: 156
# # Dealing with galaxz: 157
# # Dealing with galaxz: 158
# # Dealing with galaxz: 159
# # Dealing with galaxz: 160
# # Dealing with galaxz: 161
# # Dealing with galaxz: 162
# # Dealing with galaxz: 163
# # Dealing with galaxz: 164
# # Dealing with galaxz: 165
# # Dealing with galaxz: 166
# # Dealing with galaxz: 167
# # Dealing with galaxz: 168
# # Dealing with galaxz: 169
# # Dealing with galaxz: 170
# # Dealing with galaxz: 171
# # Dealing with galaxz: 172
# # Dealing with galaxz: 173
# # Dealing with galaxz: 174
# # Dealing with galaxz: 175
# # Dealing with galaxz: 176
# # Dealing with galaxz: 177
# # Dealing with galaxz: 178
# # Dealing with galaxz: 179
# # Dealing with galaxz: 180
# # Dealing with galaxz: 181
# # Dealing with galaxz: 182
# # Dealing with galaxz: 183
# # Dealing with galaxz: 184
# # Dealing with galaxz: 185
# # Dealing with galaxz: 186
# # Dealing with galaxz: 187
# # Dealing with galaxz: 188
# # Dealing with galaxz: 189
# # Dealing with galaxz: 190
# # Dealing with galaxz: 191
# # Dealing with galaxz: 192
# # Dealing with galaxz: 193
# # Dealing with galaxz: 194
# # Dealing with galaxz: 195
# # Dealing with galaxz: 196
# # Dealing with galaxz: 197
# # Dealing with galaxz: 198
# # Dealing with galaxz: 199
# # Dealing with galaxz: 200
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ###  ELLIPSE RUN FAILED IN ATTEMPT:  0
# ###  Error Information :  XXX Can not find the outBin: /Users/song/data/massive/simulation/riker/tng/fits/tng100_z0.4_hres_200_212615_xz_mass_ins_ellip_2.bin!
# ----------------------------------------------------------------------------------------------------
# ###  Maxsma  175.0 -->  157.5
# ----------------------------------------------------------------------------------------------------
# # Dealing with galaxz: 201
# # Dealing with galaxz: 202
# # Dealing with galaxz: 203
# # Dealing with galaxz: 204
# # Dealing with galaxz: 205
# # Dealing with galaxz: 206
# # Dealing with galaxz: 207
# # Dealing with galaxz: 208
# # Dealing with galaxz: 209
# # Dealing with galaxz: 210
# # Dealing with galaxz: 211
# # Dealing with galaxz: 212
# # Dealing with galaxz: 213
# # Dealing with galaxz: 214
# # Dealing with galaxz: 215
# # Dealing with galaxz: 216
# # Dealing with galaxz: 217
# # Dealing with galaxz: 218
# # Dealing with galaxz: 219
# # Dealing with galaxz: 220
# # Dealing with galaxz: 221
# # Dealing with galaxz: 222
# # Dealing with galaxz: 223
# # Dealing with galaxz: 224
# # Dealing with galaxz: 225
# # Dealing with galaxz: 226
# # Dealing with galaxz: 227
# # Dealing with galaxz: 228
# # Dealing with galaxz: 229
# # Dealing with galaxz: 230
# # Dealing with galaxz: 231
# # Dealing with galaxz: 232
# # Dealing with galaxz: 233
# # Dealing with galaxz: 234
# # Dealing with galaxz: 235
# # Dealing with galaxz: 236
# # Dealing with galaxz: 237
# # Dealing with galaxz: 238
# # Dealing with galaxz: 239
# # Dealing with galaxz: 240
# # Dealing with galaxz: 241
# # Dealing with galaxz: 242
# # Dealing with galaxz: 243
# # Dealing with galaxz: 244
# # Dealing with galaxz: 245
# # Dealing with galaxz: 246
# # Dealing with galaxz: 247
# # Dealing with galaxz: 248
# # Dealing with galaxz: 249
# # Dealing with galaxz: 250
# # Dealing with galaxz: 251
# # Dealing with galaxz: 252
# # Dealing with galaxz: 253
# # Dealing with galaxz: 254
# # Dealing with galaxz: 255
# # Dealing with galaxz: 256
# # Dealing with galaxz: 257
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ###  ELLIPSE RUN FAILED IN ATTEMPT:  0
# ###  Error Information :  XXX Can not find the outBin: /Users/song/data/massive/simulation/riker/tng/fits/tng100_z0.4_hres_257_255864_xz_mass_ins_ellip_2.bin!
# ----------------------------------------------------------------------------------------------------
# ###  Maxsma  175.0 -->  157.5
# ----------------------------------------------------------------------------------------------------
# # Dealing with galaxz: 258
# # Dealing with galaxz: 259
# # Dealing with galaxz: 260
# # Dealing with galaxz: 261
# # Dealing with galaxz: 262
# # Dealing with galaxz: 263
# # Dealing with galaxz: 264
# # Dealing with galaxz: 265
# # Dealing with galaxz: 266
# # Dealing with galaxz: 267
# # Dealing with galaxz: 268
# # Dealing with galaxz: 269
# # Dealing with galaxz: 270
# # Dealing with galaxz: 271
# # Dealing with galaxz: 272
# # Dealing with galaxz: 273
# # Dealing with galaxz: 274
# # Dealing with galaxz: 275
# # Dealing with galaxz: 276
# # Dealing with galaxz: 277
# # Dealing with galaxz: 278
# # Dealing with galaxz: 279
# # Dealing with galaxz: 280
# # Dealing with galaxz: 281
# # Dealing with galaxz: 282
# # Dealing with galaxz: 283
# # Dealing with galaxz: 284
# # Dealing with galaxz: 285
# # Dealing with galaxz: 286
# # Dealing with galaxz: 287
# # Dealing with galaxz: 288
# # Dealing with galaxz: 289
# # Dealing with galaxz: 290
# # Dealing with galaxz: 291
# # Dealing with galaxz: 292
# # Dealing with galaxz: 293
# # Dealing with galaxz: 294
# # Dealing with galaxz: 295
